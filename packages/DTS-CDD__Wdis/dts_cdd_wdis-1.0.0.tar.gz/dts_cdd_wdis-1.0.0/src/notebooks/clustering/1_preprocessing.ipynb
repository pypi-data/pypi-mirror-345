# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from sklearn import random_projection
from sklearn.model_selection import ParameterGrid
from sklearn.neighbors import kneighbors_graph

# %% [markdown]
# # Phase 1: Preprocessing
# 1. Load the dataset with the static features
# 2. Apply one hot encoding to the categorical features
# 3. Apply `VarianceThreshold` to delete 'constant' columns i.e. columns with 0 variance

# %%
with open("/home/luca/ml-malware-concept-drift/data/dataset/dataset.pickle", "rb") as f:
    df_1 = pickle.load(f).reset_index()
    columns_to_drop = [c for c in df_1.columns if c.startswith("ngram_")]
    print(f"Dropping {len(columns_to_drop)} columns")
    df_1 = df_1.drop(columns_to_drop, axis=1)
    print(df_1.shape)

with open(
    "/home/luca/ml-malware-concept-drift/data/dataset/dataset_opcodes.pickle", "rb"
) as f:
    df_opcodes = pickle.load(f).reset_index()
    print(df_opcodes.shape)

with open(
    "/home/luca/ml-malware-concept-drift/data/dataset/dataset_final_1_1.pickle", "rb"
) as f:
    df_ngrams = pickle.load(f)
    # df_ngrams = df_ngrams.drop([c for c in df_ngrams.columns if not c.startswith("ngram_")], axis=1).reset_index()
    print(df_ngrams.shape)

df = pd.merge(
    left=df_1,
    right=pd.merge(left=df_opcodes, right=df_ngrams, on="sample_hash"),
    on="sample_hash",
)
df = df.drop(["ms_elapsed"], axis=1)
df.head()
# Out:
# Dropping 13000 columns
# (67000, 29232)
# (67000, 2501)
# (67000, 13000)
#                                          sample_hash  generic_fileSize
# 0  cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d5302...           1666137  \
# 1  00ebebc75f61527282cee19ab7aed80693b63fbb969e71...          10543104
# 2  f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e69...             57368
# 3  d694a203bb211751669f8742db877e8ebd5eff5b126abc...           7922688
# 4  15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f...            159744
#
#    generic_fileEntropy  header_SizeOfHeaders  header_AddressOfEntryPoint
# 0             7.996651                  1024                     5358807  \
# 1             4.821304                  4096                        4512
# 2             4.979988                  4096                        9759
# 3             7.950081                  1024                      155508
# 4             5.911521                  4096                       86524
#
#    header_ImageBase  header_SizeOfImage  header_SizeOfCode
# 0           4194304             5365760             310272  \
# 1           4194304              118784              94208
# 2           4194304               57344               8192
# 3           4194304             7950336             570880
# 4           4194304              159744              86016
#
#    header_SizeOfInitializedData  header_SizeOfUninitializedData  ...
# 0                         56832                               0  ...  \
# 1                         20480                               0  ...
# 2                         45056                               0  ...
# 3                       7350784                               0  ...
# 4                         69632                               0  ...
#
#    ngram_b'\x00\x00\x84\xc0'  ngram_b'\x0c\x8bD$\x08\xd1'
# 0                       True                        False  \
# 1                      False                        False
# 2                      False                        False
# 3                       True                         True
# 4                       True                        False
#
#    ngram_b'\xfd\xff\xff\x85\xc0t'  ngram_b'ltiB'  ngram_b'e\x00a\x00'
# 0                           False          False                False  \
# 1                           False          False                 True
# 2                           False          False                False
# 3                            True           True                 True
# 4                            True           True                False
#
#    ngram_b'ExW\x00'  ngram_b'iday\x00\x00'  ngram_b'\xa4\xfe\xff\xff'
# 0             False                  False                      False  \
# 1             False                  False                      False
# 2             False                  False                      False
# 3              True                   True                       True
# 4             False                  False                      False
#
#    ngram_b'\x83\xc8\xff\xeb'  ngram_b'eAlloc'
# 0                      False            False
# 1                      False            False
# 2                      False            False
# 3                       True             True
# 4                       True            False
#
# [5 rows x 44731 columns]

# %%
categorical_columns = ["pesectionProcessed_entrypointSection_name"]
print(
    f"Unique number of elements of categorical features: {[len(set(df[c])) for c in categorical_columns]}"
)
# Out:
# Unique number of elements of categorical features: [1622]

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown="ignore", sparse_output=False, dtype=np.int32)
array_hot_encoded = enc.fit_transform(df[categorical_columns])
cat_df = pd.DataFrame(
    array_hot_encoded,
    index=df.index,
    columns=enc.get_feature_names_out(categorical_columns),
)
cat_df
# Out:
#        pesectionProcessed_entrypointSection_name_
# 0                                               0  \
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 66995                                           0
# 66996                                           0
# 66997                                           0
# 66998                                           0
# 66999                                           0
#
#        pesectionProcessed_entrypointSection_name_0
# 0                                                    0  \
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ...                                                ...
# 66995                                                0
# 66996                                                0
# 66997                                                0
# 66998                                                0
# 66999                                                0
#
#        pesectionProcessed_entrypointSection_name_a
# 0                                                    0  \
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ...                                                ...
# 66995                                                0
# 66996                                                0
# 66997                                                0
# 66998                                                0
# 66999                                                0
#
#        pesectionProcessed_entrypointSection_name_oc
# 0                                                     0  \
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 66995                                                 0
# 66996                                                 0
# 66997                                                 0
# 66998                                                 0
# 66999                                                 0
#
#        pesectionProcessed_entrypointSection_name_ta
# 0                                                     0  \
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 66995                                                 0
# 66996                                                 0
# 66997                                                 0
# 66998                                                 0
# 66999                                                 0
#
#        pesectionProcessed_entrypointSection_name_
# 0                                                   0  \
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 66995                                               0
# 66996                                               0
# 66997                                               0
# 66998                                               0
# 66999                                               0
#
#        pesectionProcessed_entrypointSection_name_0
# 0                                                   0  \
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 66995                                               0
# 66996                                               0
# 66997                                               0
# 66998                                               0
# 66999                                               0
#
#        pesectionProcessed_entrypointSection_name_1
# 0                                                   0  \
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 66995                                               0
# 66996                                               0
# 66997                                               0
# 66998                                               0
# 66999                                               0
#
#        pesectionProcessed_entrypointSection_name_@.data
# 0                                                      0   \
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 66995                                                  0
# 66996                                                  0
# 66997                                                  0
# 66998                                                  0
# 66999                                                  0
#
#        pesectionProcessed_entrypointSection_name_
#   ...
# 0                                                      0  ...  \
# 1                                                      0  ...
# 2                                                      0  ...
# 3                                                      0  ...
# 4                                                      0  ...
# ...                                                  ...  ...
# 66995                                                  0  ...
# 66996                                                  0  ...
# 66997                                                  0  ...
# 66998                                                  0  ...
# 66999                                                  0  ...
#
#        pesectionProcessed_entrypointSection_name_zsjkdbik
# 0                                                      0   \
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 66995                                                  0
# 66996                                                  0
# 66997                                                  0
# 66998                                                  0
# 66999                                                  0
#
#        pesectionProcessed_entrypointSection_name_zvmqxlbk
# 0                                                      0   \
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 66995                                                  0
# 66996                                                  0
# 66997                                                  0
# 66998                                                  0
# 66999                                                  0
#
#        pesectionProcessed_entrypointSection_name_zydklvkj
# 0                                                      0   \
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 66995                                                  0
# 66996                                                  0
# 66997                                                  0
# 66998                                                  0
# 66999                                                  0
#
#        pesectionProcessed_entrypointSection_name_zyefvnbm
# 0                                                      0   \
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 66995                                                  0
# 66996                                                  0
# 66997                                                  0
# 66998                                                  0
# 66999                                                  0
#
#        pesectionProcessed_entrypointSection_name_zzbszero
# 0                                                      0   \
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 66995                                                  0
# 66996                                                  0
# 66997                                                  0
# 66998                                                  0
# 66999                                                  0
#
#        pesectionProcessed_entrypointSection_name_| ⚛️
# 0                                                   0  \
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 66995                                               0
# 66996                                               0
# 66997                                               0
# 66998                                               0
# 66999                                               0
#
#        pesectionProcessed_entrypointSection_name_}@
# 0                                                  0  \
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 66995                                              0
# 66996                                              0
# 66997                                              0
# 66998                                              0
# 66999                                              0
#
#        pesectionProcessed_entrypointSection_name_┞ Quiz
# 0                                                     0  \
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 66995                                                 0
# 66996                                                 0
# 66997                                                 0
# 66998                                                 0
# 66999                                                 0
#
#        pesectionProcessed_entrypointSection_name_▪️GO
# 0                                                   0  \
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 66995                                               0
# 66996                                               0
# 66997                                               0
# 66998                                               0
# 66999                                               0
#
#        pesectionProcessed_entrypointSection_name_📍SWED
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ...                                                ...
# 66995                                                0
# 66996                                                0
# 66997                                                0
# 66998                                                0
# 66999                                                0
#
# [67000 rows x 1622 columns]

# %%
df = df.drop(categorical_columns, axis=1)
X = pd.merge(left=df, right=cat_df, left_index=True, right_index=True)
X = X.set_index("sample_hash")
X.head()
# Out:
#                                                     generic_fileSize
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...           1666137  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...          10543104
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...             57368
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...           7922688
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...            159744
#
#                                                     generic_fileEntropy
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...             7.996651  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...             4.821304
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...             4.979988
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...             7.950081
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...             5.911521
#
#                                                     header_SizeOfHeaders
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                  1024  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                  4096
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                  4096
#
#                                                     pesectionProcessed_entrypointSection_name_}@
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                                              0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                                              0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                                              0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                                              0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                                              0
#
#                                                     pesectionProcessed_entrypointSection_name_┞ Quiz
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                                                 0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                                                 0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                                                 0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                                                 0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                                                 0
#
#                                                     pesectionProcessed_entrypointSection_name_▪️GO
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                                               0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                                               0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                                               0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                                               0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                                               0
#
#                                                     pesectionProcessed_entrypointSection_name_📍SWED
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                                                0
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                                                0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                                                0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                                                0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                                                0
#
# [5 rows x 46351 columns]

# %%
from sklearn.feature_selection import VarianceThreshold

sel = VarianceThreshold()
X_vt = sel.fit_transform(X)
X_vt.shape
# Out:
# (67000, 46181)

# %%
features_mask = sel.get_support()
zero_var_columns = set(X.columns) - set(X.loc[:, features_mask].columns)
# with open("zero_var_columns.txt", 'w') as file:
#     for c in zero_var_columns:
#         file.write(c + '\n')

# %%
sdf = pd.DataFrame(X_vt, columns=list(set(X.columns) - zero_var_columns), index=X.index)
sdf.head()
# Out:
#                                                     imp___vbafreevar
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...         1666137.0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...        10543104.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...           57368.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...         7922688.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...          159744.0
#
#                                                     str_Invalid  str_|$$}
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...     7.996651    1024.0  \
#
#                                                     str_D$$;T$
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...         0.0
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...         0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...         0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...         0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...         0.0
#
# [5 rows x 46181 columns]

# %% [markdown]
# ## Scaler: Apply MinMax scaling before PCA

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
sdf_normalized = scaler.fit_transform(sdf)
sdf_normalized = np.nan_to_num(sdf_normalized)
# Out:
# array([[2.85713512e-03, 9.99581391e-01, 1.46094805e-07, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.80892343e-02, 6.02390637e-01, 9.25267101e-07, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.66281839e-05, 6.22239813e-01, 9.25267101e-07, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [1.28784385e-04, 5.62105944e-01, 1.46094805e-07, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.28784385e-04, 5.62147088e-01, 1.46094805e-07, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.13787262e-04, 7.54936930e-01, 9.25267101e-07, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
sdf_normalized = pd.DataFrame(sdf_normalized, columns=sdf.columns, index=sdf.index)

# %%
sdf_normalized.head()
# Out:
#                                                     imp___vbafreevar
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...          0.002857  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...          0.018089
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...          0.000097
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...          0.013593
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...          0.000272
#
#                                                     str_Invalid      str_|$$}
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...     0.999581  1.460948e-07  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...     0.602391  9.252671e-07
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...     0.622240  9.252671e-07
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...     0.993756  1.460948e-07
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...     0.738761  9.252671e-07
#
#                                                     str_D$(p  imp_mmioseek
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...  0.020755      0.002018  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...  0.000016      0.002018
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...  0.000036      0.002018
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...  0.000601      0.002018
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...  0.000333      0.002018
#
#                                                     ngram_b'ndCl'
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...       0.003215  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...       0.000071
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...       0.000034
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...       0.004763
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...       0.000095
#
#                                                     str_1!1+12161<1@1F1P1Z1d1n1u1y1
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                         0.000072  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                         0.000022
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                         0.000002
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                         0.000133
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                         0.000020
#
#                                                     str_L$@H3
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...   0.000013  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...   0.000005
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...   0.000010
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...   0.001711
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...   0.000016
#
#                                                     opcode_xor mov jmp
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                 0.0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                 0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                 0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                 0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                 0.0
#
#                                                     str_l$@E  ...
# sample_hash                                                   ...
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...  0.000016  ...  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...  0.000016  ...
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...  0.000016  ...
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...  0.000016  ...
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...  0.000016  ...
#
#                                                     ngram_b'a\xff\xff\xff'
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                     0.0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                     0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                     0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                     0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                     0.0
#
#                                                     ngram_b'\x8aF\x03\x88G\x03'
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                          0.0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                          0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                          0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                          0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                          0.0
#
#                                                     ngram_b'\xaa\x01\x00\x00'
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...                        0.0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...                        0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...                        0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...                        0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...                        0.0
#
#                                                     str_-tvf  str_June
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...       0.0       0.0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...       0.0       0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...       0.0       0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...       0.0       0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...       0.0       0.0
#
#                                                     str_~DWP  ngram_b'EndOfF'
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...       0.0              0.0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...       0.0              0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...       0.0              0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...       0.0              0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...       0.0              0.0
#
#                                                     str_u39}  str_;K$|
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...       0.0       0.0  \
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...       0.0       0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...       0.0       0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...       0.0       0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...       0.0       0.0
#
#                                                     str_D$$;T$
# sample_hash
# cfa2d5eeac7de9f134cb2e36d54a5c4053f62fdf9d53029...         0.0
# 00ebebc75f61527282cee19ab7aed80693b63fbb969e715...         0.0
# f45e6ca3a2bbbaa1c514d81abe9daaa47f7d41da500e693...         0.0
# d694a203bb211751669f8742db877e8ebd5eff5b126abc4...         0.0
# 15c9feb810c48ffef1c7e32cbe58a11037da94e958fb1f3...         0.0
#
# [5 rows x 46181 columns]

# %%
sdf_normalized.to_csv("normalized_dataset.csv", escapechar="\\")

# %% [markdown]
# # Phase 2: Apply Incremental PCA

# %%
del cat_df
del df_opcodes
del df_ngrams
del df_1
del X_vt
del sdf
del X
del df

# %%
from sklearn.decomposition import IncrementalPCA

pca_arr = [
    IncrementalPCA(n_components=n_components) for n_components in [300, 400, 500]
]
for pca in pca_arr:
    print("Fitting")
    pca.fit(sdf_normalized)
# Out:
# Fitting

# %%
# from sklearn.decomposition import SparsePCA
# sparse_pca = SparsePCA(n_components=500)
# X_std_scaler_spca = sparce_pca.fit_transform(X_vt_df)

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.8560958970577225

# %%
loading_matrix = pca.components_
loading_matrix.shape
# Out:
# (300, 46181)

# %%
fea_magnitude = np.linalg.norm(loading_matrix, axis=0)
fea_magnitude.shape
# Out:
# (46181,)

# %%
feature_idx = np.argsort(-1 * fea_magnitude)
fea_magnitude[feature_idx[0:8000]]
# Out:
# array([0.22063661, 0.22054637, 0.22030525, ..., 0.11959986, 0.11959809,
#        0.11959116])

# %%
print(feature_idx[0:8000])
# Out:
# [40072 37917 33304 ... 40767 23999 41776]

# %%
print(df.columns[feature_idx[0:8000]])  ### print out the top 8000 featuers' names
# Out:
# Index(['str_InitializeAcl', 'ngram_b'apFree'', 'str_u)j,',
#        'ngram_b'\x04\x00\x00\x83'', 'str_Buginese',
#        'pesectionProcessed_entrypointSection_name_aedcqpmu', 'opcode_and pop',
#        'ngram_b'\x00\x00\x00\x00\x00\xd6'', 'str_t 9^', 'str_QQQQP',
#        ...
#        'str_\$ W', 'str_DockClient', 'str_TClass', 'ngram_b'\x033\xc0@'',
#        'ngram_b'\x8bE\x0cS'', 'str_NoRun', 'str_;$;(;.;2;8;B;L;V;`;g;k;q;u;{;',
#        'ngram_b'\x00\x00\x81\x9f'', 'str_TRttiInstancePropertyEx',
#        'ngram_b'lign''],
#       dtype='object', length=8000)

# %%
sdf_subcol = sdf_normalized[
    :, feature_idx[0:8000]
]  ### choosing the top features only for clustering
sdf_subcol.shape
# Out:
# (6700, 8000)

# %%
#### clustering
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering
from matplotlib import pyplot as plt


def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)


# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(
    linkage="complete", metric="cosine", distance_threshold=0, n_clusters=None
)
# model = model.fit(sdf_subcol)
model = model.fit(sdf_normalized)
plt.title("Hierarchical Clustering Dendrogram")
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode="level", p=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      29 model = AgglomerativeClustering(linkage='complete', metric='cosine', distance_threshold=0, n_clusters=None)
#      30 #model = model.fit(sdf_subcol)
# ---> 31 model = model.fit(sdf_normalized)
#      32 plt.title("Hierarchical Clustering Dendrogram")
#      33 # plot the top three levels of the dendrogram
#
# NameError: name 'sdf_normalized' is not defined

# %%
model = AgglomerativeClustering(
    linkage="complete", metric="cosine", n_clusters=670
).fit(sdf_normalized)

labels = model.labels_
true_labels = []
for k in range(670):
    true_labels.extend(10 * [k])

from sklearn.metrics import normalized_mutual_info_score, adjusted_mutual_info_score

print(normalized_mutual_info_score(true_labels, labels))
print(adjusted_mutual_info_score(true_labels, labels))
